# %%
# import sys
# !C:\Users\Alex\anaconda3\envs\tfenv\python.exe -m pip install torch
# Out:
# ...
#    ---------------------------------------- 111.0/111.0 MB 10.3 MB/s  0:00:10
# ...
#    ---------------------------------------- 1.7/1.7 MB 10.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 6.3/6.3 MB 11.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 536.2/536.2 kB 8.8 MB/s  0:00:00
# ...
#
# ...
#   WARNING: The script isympy.exe is installed in 'C:\Users\Alex\anaconda3\envs\tfenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\Alex\anaconda3\envs\tfenv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
